# %%
import  numpy as np
import pandas as pd
import scipy
from scipy import stats
from collections import Counter
from scipy.stats import binom
from scipy.stats import poisson
from scipy.stats import norm
from scipy.stats import t,expon

# %%
binom.pmf(40,80,0.7)
# Out:
# np.float64(8.32164865259082e-05)

# %%
1- binom.cdf(50,80,0.7)
# Out:
# np.float64(0.9084021100368282)

# %%
binom.sf(50,80,0.7)
# Out:
# np.float64(0.9084021100368282)

# %%
poisson.pmf(7,5)
# Out:
# np.float64(0.10444486295705395)

# %%
poisson.cdf(7,5)
# Out:
# np.float64(0.8666283259299925)

# %% [markdown]
# # Probability Distribution Function (cont)

# %% [markdown]
# # Normal Distribution

# %%
norm.cdf(43,45,2.8)
# Out:
# np.float64(0.2375252620269765)

# %%
z=(43-45)/2.8
z
# Out:
# -0.7142857142857143

# %%
norm.cdf(z,0,1) #(z,mean,std-dev)
# Out:
# np.float64(0.2375252620269765)

# %%
norm.cdf(z)
# Out:
# np.float64(0.2375252620269765)

# %%
norm.cdf(1.73)
# Out:
# np.float64(0.9581848623864051)

# %% [markdown]
# ## Student's Distribution

# %%
t.cdf(15,18,1.8)
# Out:
# np.float64(0.9999999999463915)

# %%
z=(14-15.3)/1.8
z
# Out:
# -0.7222222222222227

# %%
t.cdf(z,14)
# Out:
# np.float64(0.2410240907076217)

# %% [markdown]
# ## Exponential Distribution

# %%
365*24  #hrs in a year
# Out:
# 8760

# %%
8760/200 #Mean time between failures (units wil be hrs/incident)
# Out:
# 43.8

# %%
1/43.8 # rate of failure
# Out:
# 0.022831050228310504

# %%
expon.cdf(100,scale=4.8)
# Out:
# np.float64(0.9999999991042263)

# %%
24/80
# Out:
# 0.3

# %%
expon.cdf(1,scale=0.3)
# Out:
# np.float64(0.9643260066527476)

# %%
# on avg 30 times in a 45day 
(45*8)/30
# Out:
# 12.0

# %%
expon.cdf(8,scale=12)
# Out:
# np.float64(0.486582880967408)
